# %%
# import lib
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/proceed/Clean_data.csv')

# %%
data.head()
# Out:
#   accounting_date  company_code customer_code  customer_district_code  \
# 0      2012-05-09           101     411800601                     410
# 1      2012-02-16           101     361000403                     300
# 2      2012-05-09           101     361000403                     300
# 3      2012-05-18           101     565540415                     500
# 4      2012-01-09           101     565540415                     500
#
#      item_code       business_chain_l1_name salesperson_code  \
# 0  GENIE8WWWBC              ElectraCorp Ltd             T612
# 1  GENIE8WWWBC        BrightPower Solutions             P345
# 2  GENIE8WWWBC        BrightPower Solutions             P345
# 3  GENIE8WWWBC  Global Electric Wholesalers             T504
# 4  GENIE8WWWBC  Global Electric Wholesalers             T504
#
#             market_segment  value_sales  value_cost  ...  \
# 0  Commercial & Industrial       218.40    178.1976  ...
# 1  Commercial & Industrial        38.28     25.4568  ...
# ...

# %% [markdown]
# 1. Question 1: What factors impact sales revenue in different market segments?
# Selected Variables
#
# Dependent Variable: value_sales
# Independent Variables:
# value_quantity: Quantity of items sold
# market_segment: Market segment (categorical variable)
# value_price_adjustment: Adjustment in price
# day_gap: The gap in days between certain events (if relevant to timing effects)
# light_source_LED and light_source_Traditional: Type of light source (already one-hot encoded)

# %% [markdown]
# 1. Question 2: How does profit margin correlate with operational factors like product type, cost, and sales quantity?
# Objective: To determine the key drivers of profit margin, helping LuminaTech identify products or regions that contribute most to profitability.
#
# Dependent Variable: profit_margin

# %%
# Display the column names
data.columns
# Out:
# Index(['accounting_date', 'company_code', 'customer_code',
#        'customer_district_code', 'item_code', 'business_chain_l1_name',
#        'salesperson_code', 'market_segment', 'value_sales', 'value_cost',
#        'value_quantity', 'value_price_adjustment', 'currency',
#        'invoice_number', 'line_number', 'invoice_date',
#        'customer_order_number', 'order_date', 'dss_update_time', 'day_gap',
#        'order_group', 'value_sales_log_plus1_transformed',
#        'value_cost_log_plus1_transformed',
#        'value_quantity_log_plus1_transformed', 'business_area_code_DLT',
#        'business_area_code_LMP', 'business_area_code_OTH',
#        'business_area_code_Other', 'business_area_code_SUR',
#        'item_group_code_Other', 'item_class_code_LMP01',
#        'item_class_code_LMP03', 'item_class_code_LMP04',
#        'item_class_code_LMP05', 'item_class_code_Other', 'item_type_5',
#        'item_type_6', 'item_type_7', 'item_type_Other',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1971500 entries, 0 to 1971499
# Data columns (total 85 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   accounting_date                         object
#  1   company_code                            int64
#  2   customer_code                           object
#  3   customer_district_code                  int64
#  4   item_code                               object
#  5   business_chain_l1_name                  object
#  6   salesperson_code                        object
#  7   market_segment                          object
#  8   value_sales                             float64
#  9   value_cost                              float64
#  10  value_quantity                          float64
#  11  value_price_adjustment                  int64
#  12  currency                                object
#  13  invoice_number                          int64
# ...

# %%
# Filter only numeric and boolean columns for correlation calculation
data_numeric = data.select_dtypes(include=['number', 'bool'])

# Calculate the correlation matrix
corr_matrix = data_numeric.corr()

# Show correlations with 'value_sales', sorted by absolute value in descending order
top_10_corr_with_sales = corr_matrix['value_sales'].abs().sort_values(ascending=False).head(10)
print(top_10_corr_with_sales)
# Out:
# value_sales                          1.000000
# value_cost                           0.949025
# Profit                               0.804550
# Transformed_Profit                   0.636567
# Unit_Price                           0.243199
# value_sales_log_plus1_transformed    0.224283
# Transformed_Unit_Price               0.203826
# value_quantity                       0.185489
# bonus_group_code_Trade               0.165260
# value_cost_log_plus1_transformed     0.145786
# Name: value_sales, dtype: float64
